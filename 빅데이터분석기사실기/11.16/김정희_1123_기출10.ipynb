# %% [markdown]
# # 📌 기출 10회

# %% [markdown]
# ### 작업형1 문제 1
# 제공된 데이터(subject_performance.csv)는 학생들이 각 문제를 풀었을 때의 정답 여부를 기록한 자료이다. 각 문제는 대주제와 소주제로 분류되어 있다.
# 아래 수행 순서에 따라 데이터를 처리한 뒤, 구한 값을 [제출 형식]에 맞춰 답안 페이지에 입력하시오.
#
# 제공 데이터
# - major_topic : 대주제
# - sub_topic : 소주제
# - student_id : 학생 ID
# - is_correct : 정답 여부(1: 정답, 0: 오답)
#
# 수행 순서
# 1. 소주제별 정답률을 계산한다.
#     - 정답률 = (해당 소주제의 정답 개수) / (해당 소주제의 전체 문제 풀이 수)
# 2. 소주제들의 정답률 중 3번째로 높은 값을 구하시오.
#     - 단, 정답률이 같은 경우 하나로 취급한다. 정답률이 0.7, 0.7, 0.6, 0.5인 경우, 세 번째로 높은 값은 0.5이다.
#
# [제출형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/subject_performance.csv")

cond1 = df.value_counts('sub_topic')

cond2 = df.groupby('sub_topic')['is_correct'].sum()
ratio = cond2/cond1

print(ratio.sort_values( ascending = False))
 
result = ratio[3]
print(result)
# Out:
# sub_topic
# Algorithms              0.787162
# Linear Algebra          0.787162
# Mechanics               0.693727
# Calculus                0.673913
# Quantum                 0.667774
# Electromagnetism        0.658621
# Operating Systems       0.658621
# Discrete Mathematics    0.643836
# Databases               0.640523
# dtype: float64
# 0.6438356164383562
# C:\Users\김금영\AppData\Local\Temp\ipykernel_19560\175777442.py:11: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result = ratio[3]

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/subject_performance.csv")


# cond1 = df.groupby('sub_topic')['is_correct']
# print(cond1)
# correct_ratio = cond1.sum()/cond1.count()
# print(correct_ratio)
# correct_ratio = correct_ratio.sort_values(ascending = False)
# print(correct_ratio)
# result = correct_ratio.values[3]
# print(result)

cond1 = df.groupby('sub_topic')['is_correct']
correct_ratio = cond1.sum()/cond1.count()

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/subject_performance.csv")

# 소주제별 정답률을 계산
print('\n======소주제별 정답률=======')
gp = df.groupby('sub_topic')['is_correct']
correct_ratio = gp.sum() / gp.count()
print(correct_ratio)


# 소주제들의 정답률 중 3번째로 높은 값을 구하시오. (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.674
print('\n======정답률 중 3번째로 높은 값=======')
correct_ratio = correct_ratio.sort_values(ascending=False)
print(correct_ratio)
rst = correct_ratio.values[3]
print(round(rst,3))
# Out:
# ======소주제별 정답률=======
# sub_topic
# Algorithms              0.787162
# Calculus                0.673913
# Databases               0.640523
# Discrete Mathematics    0.643836
# Electromagnetism        0.658621
# Linear Algebra          0.787162
# Mechanics               0.693727
# Operating Systems       0.658621
# Quantum                 0.667774
# Name: is_correct, dtype: float64
#
# ======정답률 중 3번째로 높은 값=======
# sub_topic
# Algorithms              0.787162
# Linear Algebra          0.787162
# Mechanics               0.693727
# Calculus                0.673913
# Quantum                 0.667774
# Electromagnetism        0.658621
# Operating Systems       0.658621
# Discrete Mathematics    0.643836
# Databases               0.640523
# Name: is_correct, dtype: float64
# 0.674

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/subject_performance.csv")

# 소주제별 정답률을 계산
print('\n======소주제별 정답률=======')
correct_ratio = df.groupby('sub_topic')['is_correct'].mean()
print(correct_ratio)


# 소주제들의 정답률 중 3번째로 높은 값을 구하시오. (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.674
print('\n======정답률 중 3번째로 높은 값=======')
correct_ratio = correct_ratio.sort_values(ascending=False).drop_duplicates()
rst = correct_ratio.iloc[2]
print(round(rst,3))
# Out:
# ======소주제별 정답률=======
# sub_topic
# Algorithms              0.787162
# Calculus                0.673913
# Databases               0.640523
# Discrete Mathematics    0.643836
# Electromagnetism        0.658621
# Linear Algebra          0.787162
# Mechanics               0.693727
# Operating Systems       0.658621
# Quantum                 0.667774
# Name: is_correct, dtype: float64
#
# ======정답률 중 3번째로 높은 값=======
# 0.674

# %% [markdown]
# ### 작업형1 문제2
# 제공된 데이터(cafe_sales.csv)는 2024년 4월부터 2025년 12월까지의 카페 메뉴 판매 이력이다. 소문항을 각각 구한 다음 [제출 형식]에 맞춰 답안 페이지에 입력하시오.
#
# 제공 데이터
# - order_date : 주문 날짜 (예 2024.05.24 13:22)
# - category : 음료/디저트 종류 (예 coffee, tea …)
# - item : 메뉴명
# - price : 판매 금액
#
# 소문항
#
# 2-1. 연-월별 총 매출액을 계산하여 큰 순서대로 정렬했을 때, 2번째로 큰 매출액을 입력하시오.
#
# 2-2. 연-월별 총 매출액이 4번째로 큰 연-월을 찾으시오. 해당 연-월의 데이터에서 카테고리별 매출 합계를 계산하고, 그중 최댓값을 입력하시오.
# [제출 형식] 정수로 작성

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/cafe_sales.csv")

df['order_date'] = pd.to_datetime(df['order_date'])

df['order_date'] = df['order_date'].dt.to_period('M')

cond1 = df.groupby('order_date')['price'].sum()



print(cond1.sort_values(ascending = False))

print("328741")
print("2024-10 ")
# Out:
# order_date
# 2025-03    347848
# 2025-07    328741
# 2025-05    311810
# 2024-10    309026
# 2025-08    308798
# 2025-10    305833
# 2024-05    303992
# 2024-07    300886
# 2025-06    292062
# 2024-04    291906
# 2025-04    284055
# 2025-09    277927
# 2025-02    276728
# 2025-11    262399
# 2025-12    261205
# 2024-08    241602
# 2024-12    237023
# 2024-09    230353
# 2024-06    230115
# 2025-01    211567
# 2024-11    210704
# Freq: M, Name: price, dtype: int64
# 328741
# 2024-10

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/cafe_sales.csv")
print(df.head(1))
df['order_date']= pd.to_datetime(df['order_date'])

df['year'] = df['order_date'].dt.year
df['month'] = df['order_date'].dt.month

print(df.head(3))
# 틀린것 - groupby 할떄 2개 넣으려면 리스트 [] 형식으로 넣어야함
df = df.groupby(['year','month'])['price'].sum()

df = df.sort_values( ascending = False)

print(df.head(3))

print(df.iloc[1])
# Out:
#          order_date category      item  price
# 0  2025.03.08 23:30      tea  GreenTea   6861
#            order_date  category      item  price  year  month
# 0 2025-03-08 23:30:00       tea  GreenTea   6861  2025      3
# 1 2025-10-01 13:05:00    coffee     Latte   6080  2025     10
# 2 2025-04-30 17:32:00  smoothie     Mango   6116  2025      4
# year  month
# 2025  3        347848
#       7        328741
#       5        311810
# Name: price, dtype: int64
# 328741

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/cafe_sales.csv")

# 연-월별 총 매출액을 계산하여 큰 순서대로 정렬했을 때, 2번째로 큰 매출액을 입력하시오.
# 답: 328741
print('\n======2번째로 큰 매출액=======')
df['order_date'] = pd.to_datetime(df['order_date'])
df['order_date'] = df['order_date'].dt.to_period('M')
gp = df.groupby('order_date')['price'].sum().sort_values(ascending=False)
second_largest =  gp.nlargest(2)
print(second_largest)
print(second_largest.values[1])


# 연-월별 총 매출액이 4번째로 큰 연-월을 찾으시오. 
# 답: 2024-10
print('\n======4번째로 큰 연-월=======')
four_largest_index = gp.index[3]
print(four_largest_index)




# 해당 연-월의 데이터에서 카테고리별 매출 합계를 계산하고, 그중 최댓값을 입력하시오.
# 답: 104660
print('\n======최댓값=======')
cond = df['order_date'] == four_largest_index
df = df.loc[cond]
gp = df.groupby('category')['price'].sum()
rst = gp.max()
print(rst)
# Out:
# ======2번째로 큰 매출액=======
# order_date
# 2025-03    347848
# 2025-07    328741
# Freq: M, Name: price, dtype: int64
# 328741
#
# ======4번째로 큰 연-월=======
# 2024-10
#
# ======최댓값=======
# 104660

# %%
# 시험장에서 dt.to_period가 기억이 안날 때 방법1 - dt.year, dt.month, str.zfill 사용 
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/cafe_sales.csv")

# 연-월별 총 매출액을 계산하여 큰 순서대로 정렬했을 때, 2번째로 큰 매출액을 입력하시오.
# 답: 328741
print('\n======연도바꾸기=======')
df['order_date'] = pd.to_datetime(df['order_date'])
df['order_date'] = df['order_date'].dt.year.astype(str) + "-" + df['order_date'].dt.month.astype(str).str.zfill(2)
print(df.head())
# Out:
# ======연도바꾸기=======
#   order_date  category      item  price
# 0    2025-03       tea  GreenTea   6861
# 1    2025-10    coffee     Latte   6080
# 2    2025-04  smoothie     Mango   6116
# 3    2025-12       tea  BlackTea   7807
# 4    2024-04   dessert    Cookie   7964

# %%
# 시험장에서 dt.to_period가 기억이 안날 때 방법2 - 문자열 슬라이싱 
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/cafe_sales.csv")

# 연-월별 총 매출액을 계산하여 큰 순서대로 정렬했을 때, 2번째로 큰 매출액을 입력하시오.
# 답: 328741
print('\n======연도바꾸기=======')
year = df['order_date'].str[:4]
month = df['order_date'].str[5:7]
df['order_date'] = year + "-" + month
print(df.head())
# Out:
# ======연도바꾸기=======
#   order_date  category      item  price
# 0    2025-03       tea  GreenTea   6861
# 1    2025-10    coffee     Latte   6080
# 2    2025-04  smoothie     Mango   6116
# 3    2025-12       tea  BlackTea   7807
# 4    2024-04   dessert    Cookie   7964

# %% [markdown]
# ### 작업형1 문제 3
# 제공된 데이터(hamspam.csv)는 문자 메시지 내용과 스팸 여부를 담고 있다.
# 아래 수행 순서에 따라 데이터를 처리한 뒤, 구한 값을 [제출 형식]에 맞춰 답안 페이지에 입력하시오.
#
# 제공 데이터
# - label : 메시지 구분 (spam: 스팸, ham: 정상)
# - text : 메시지
#
# 수행 순서
# 1. 각 메시지의 단어 개수를 띄어쓰기(공백) 기준으로 계산하시오.
# 2. 스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수를 각각 구하시오.
# 3. 두 평균의 차이의 절댓값을 구하여 입력하시오.
#
# [제출형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/hamspam.csv")
df['count'] = df['text'].str.split().str.len()


cond1 = df.groupby('label')['count'].mean()
print(cond1)
result = abs(cond1[1]-cond1[0])
print(round(result,3))
# Out:
# label
# ham     10.070026
# spam    10.022919
# Name: count, dtype: float64
# 0.047
# C:\Users\김금영\AppData\Local\Temp\ipykernel_19560\4068759383.py:10: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result = abs(cond1[1]-cond1[0])

# %%
# 풀이방법1 
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/hamspam.csv")
df['개수'] = df['text'].str.split().str.len()

cond1 = df.groupby('label')['개수'].mean()

print(cond1)

result = round(abs(cond1[0]-cond1[1]),3)

print(result)
# Out:
# label
# ham     10.070026
# spam    10.022919
# Name: 개수, dtype: float64
# 0.047
# C:\Users\김금영\AppData\Local\Temp\ipykernel_19560\395217328.py:12: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   result = round(abs(cond1[0]-cond1[1]),3)

# %%
# 풀이방법1 
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/hamspam.csv")

# 각 메시지의 단어 개수를 띄어쓰기(공백) 기준으로 계산하시오.
print('\n======단어 개수를 띄어쓰기(공백) 기준으로 계산=======')
df['word_cnt'] = df['text'].str.split().str.len()
print(df.head())

#1. str split으로 분리

df['개수'] = df['test'].str.split().str.len()
print(df.head())
# 스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수를 각각 구하시오.
print('\n======스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수=======')
gp = df.groupby('label')['word_cnt'].mean()
avg_df = gp.reset_index(drop=True)
print(avg_df)

# 두 평균의 차이의 절댓값을 구하여 입력하시오. (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.047
print('\n======두 평균의 차이의 절댓값=======')
a = avg_df.loc[0]
b = avg_df.loc[1]
rst = abs(a-b)
print(round(rst,3))
# Out:
# ======단어 개수를 띄어쓰기(공백) 기준으로 계산=======
#   label                                               text  word_cnt
# 0   ham  Incididunt tempor elit sit do aliqua eiusmod a...        10
# 1   ham       Adipiscing tempor lorem ipsum dolore tempor.         6
# 2  spam    Tempor tempor magna sed incididunt consectetur.         6
# 3   ham  Consectetur incididunt amet adipiscing amet lo...        12
# 4   ham                  Sit ipsum labore sit do sit elit.         7
#
# ======스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수=======
# 0    10.070026
# 1    10.022919
# Name: word_cnt, dtype: float64
#
# ======두 평균의 차이의 절댓값=======
# 0.047

# %%
# 풀이방법2
import pandas as pd

# 데이터 불러오기
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_1/hamspam.csv")

# 각 메시지의 단어 개수를 띄어쓰기(공백) 기준으로 계산하시오.
print('\n======단어 개수를 띄어쓰기(공백) 기준으로 계산=======')
df['word_cnt'] = df['text'].str.count(" ") + 1
print(df.head())

# 스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수를 각각 구하시오.
print('\n======스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수=======')
spam_cond = df['label'] == 'spam'
normal_cond = df['label'] == 'ham'

spam_mean = df.loc[spam_cond, 'word_cnt'].mean()
normal_mean = df.loc[normal_cond, 'word_cnt'].mean()

print(spam_mean)
print(normal_mean)

# 두 평균의 차이의 절댓값을 구하여 입력하시오. (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.047
print('\n======두 평균의 차이의 절댓값=======')
rst = abs(spam_mean - normal_mean )
print(round(rst,3))
# Out:
# ======단어 개수를 띄어쓰기(공백) 기준으로 계산=======
#   label                                               text  word_cnt
# 0   ham  Incididunt tempor elit sit do aliqua eiusmod a...        10
# 1   ham       Adipiscing tempor lorem ipsum dolore tempor.         6
# 2  spam    Tempor tempor magna sed incididunt consectetur.         6
# 3   ham  Consectetur incididunt amet adipiscing amet lo...        12
# 4   ham                  Sit ipsum labore sit do sit elit.         7
#
# ======스팸 메시지의 평균 단어 개수와 정상 메시지의 평균 단어 개수=======
# 10.02291917973462
# 10.07002561912895
#
# ======두 평균의 차이의 절댓값=======
# 0.047

# %% [markdown]
# ## 📌 작업형2

# %% [markdown]
# ### 문제
# 제공된 학습용 데이터(train.csv)는 서울시 각 시군구별 건물 및 시설 현황 데이터이다.
# 학습용 데이터를 활용하여 총가스사용량을 예측하는 모형을 개발하고, 모형을 평가용 데이터(test.csv)에 적용하여 총가스사용량을 예측하시오.
#
# 예측 결과는 아래의 [유의 사항]과 [제출 형식]을 준수하여, CSV 파일(result.csv)을 생성하는 코드를 제출하시오.
#
# ---
#
# [유의 사항]
#
# ① 예측 결과는 RMSE(Root Mean Squared Error) 평가 지표에 따라 평가함
#
# ② 타겟 변수(총가스사용량)는 일부 값이 0으로 기재되어 있으며, 이는 결측치를 대체한 값임.
#
# [제출 형식]
#
# ① CSV 파일명: result.csv
#
# ② 예측 총가스사용량 컬럼명: pred
#
# ③ 제출 컬럼 개수: pred 컬럼 1개
#
# ④ 평가용 데이터 개수와 예측 결과 데이터 개수 일치: 1,476개
#
# ---
#
# [제공 데이터]
# - train.csv: 학습용 데이터, 약 3,196개
# - test.csv: 평가용 데이터, 약 1,476개
# 평가용 데이터에는 총가스사용량 컬럼 미제공
#
# [CSV 파일 형식 및 확인 방법]
# - CSV 파일명: result.csv
# - 예측 총가스사용량 컬럼명: pred
# - 제출 CSV 파일 예시
# ~~~
# pred
# 8790
# 14748
# 21560
# 761
# ~~~

# %%
# 원핫인코딩 + 랜포:  673.5987038347059
# 원핫인코딩 + lightgbm: 741.9117749289708
# 레이블인코딩 + 랜포: 690.1602218823608
# 레이블인코딩 + lightgbm: 784.7032383890951

# 데이터 불러오기
import pandas as pd
train = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_2/gas_train.csv")
test = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_2/gas_test.csv")

# 문제정의
# 문제종류: 회귀. 
# 예측컬럼: 총가스사용량
# 평가지표: RMSE. E가 들어가면 회귀이다. 
# 결과파일: result.csv


# 탐색적데이터분석
print("\n====데이터 크기=====")
print(train.shape, test.shape)

print("\n====데이터 정보=====")
print(train.info())

print("\n====train 결측치=====")
print(train.isnull().sum())

print("\n====test 결측치=====")
print(test.isnull().sum())

print("\n====카테고리 비교=====")
print(train.describe(include = ['object','category']))
print(test.describe(include = ['object','category']))

print("\n====target 기술통계=====")
print(train['총가스사용량'].describe())

# 데이터 전처리
cond = train['총가스사용량'] == 0 # 가스 사용량이 0인 경우는 흔치 않기에 삭제하여 준다. 
train = train.loc[~cond]
target = train.pop('총가스사용량')


# 원핫인코딩
combined = pd.concat([train,test])
combined_dummies = pd.get_dummies(combined)
len_train = len(train)
train = combined_dummies[:len_train]
test = combined_dummies[len_train:]


# 데이터 분할
print("\n====데이터 분할=====")
from sklearn.model_selection import train_test_split
X_tr, X_val, y_tr, y_val = train_test_split(
    train,
    target,
    test_size= 0.2,
    random_state = 0
)
print(X_tr.shape, X_val.shape, y_tr.shape, y_val.shape)

# 머신러닝 학습 및 평가
print("\n====RMSE 평가지표=====")
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor(random_state=0)
rf.fit(X_tr, y_tr)
pred = rf.predict(X_val)

from sklearn.metrics import root_mean_squared_error
score = root_mean_squared_error(y_val, pred)
print("RMSE 평가지표:",score)

# 예측 및 파일 제출
pred = rf.predict(test)
submit = pd.DataFrame({'pred' : pred})
submit.to_csv('result.csv', index=False)

# 검증

# pred, test 행 수 비교
print("\n====pred, test 행 수 비교=====")
print(pred.shape, test.shape)

# result.csv 예시 
print("\n====result.csv 예시 =====")
print(pd.read_csv('result.csv').head())
# Out:
# ====데이터 분할=====
# (2511, 25) (628, 25) (2511,) (628,)
#
# ====RMSE 평가지표=====
# RMSE 평가지표: 673.8026644431536
#
# ====pred, test 행 수 비교=====
# (1476,) (1476, 25)
#
# ====result.csv 예시 =====
#            pred
# 0  10370.326884
# 1  10712.127501
# 2   8822.889618
# 3  10370.326884
# 4  11213.409604

# %% [markdown]
# ## 📌작업형3

# %% [markdown]
# ### 문제1
#
# 제공된 데이터(attrition.csv)는 직원의 나이, 연봉, 근무 특성 등에 따른 이직 여부(attrition)에 관한 자료이다.
# 이 데이터를 이용하여 로지스틱 회귀분석(Logistic Regression)을 수행하고, 제시된 소문항에 답하시오.
#
# [제공 데이터]
# - attrition : 이직 여부 (0 = 잔류, 1 = 이직) 종속변수
# - age : 나이 (정수형)
# - income : 연봉 (정수형)
# - overtime : 초과근무 여부 (0 = 아니오, 1 = 예)
#
# 1. 로지스틱 회귀모델을 적합한 후, p-value가 0.05보다 작은 변수의 회귀계수를 구하시오. 단 절편항(상수항)은 제외한다. (반올림하여 소수 셋째 자리까지 작성)
#
# 2. 나이(age)가 1 증가할 때 이직할 오즈비(Odds Ratio)를 구하시오.(반올림하여 소수 셋째 자리까지 작성)
#
# 3. 새로운 직원(age=40, income=4500, overtime=1)에 대해, 모델을 이용하여 이직 확률을 예측하시오.(반올림하여 소수 셋째 자리까지 작성)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/attrition.csv")

# 1. 로지스틱 회귀모델을 적합한 후, p-value가 0.05보다 작은 변수의 회귀계수를 구하시오. 단 절편항(상수항)은 제외한다. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: -0.002
print(df.head())
from statsmodels.formula.api import logit
formula = 'attrition ~ age + income + overtime'

model = logit(formula, data = df).fit()

print(model.pvalues)
print(round(model.params['income'],3))


# 2. 나이(age)가 1 증가할 때 이직할 오즈비(Odds Ratio)를 구하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.996

import numpy as np

result = np.exp(model.params['age']*1)
print(round(result,3))


# 3. 새로운 직원(age=40, income=4500, overtime=1)에 대해, 모델을 이용하여 이직 확률을 예측하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.697

new_data = pd.DataFrame({'age':[40],'income':[4500],'overtime':[1]})

pred = model.predict(new_data)

print(round(pred,3))
# Out:
#    attrition  age  income  overtime
# 0          0   44    6467         1
# 1          0   41    6201         0
# 2          1   25    4017         1
# 3          0   28    6360         1
# 4          1   58    2369         0
# Optimization terminated successfully.
#          Current function value: 0.387298
#          Iterations 7
# Intercept    7.582302e-220
# age           2.268857e-01
# income        0.000000e+00
# overtime      5.915511e-01
# dtype: float64
# -0.002
# 0.996
# 0    0.697
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/attrition.csv")

# 1. 로지스틱 회귀모델을 적합한 후, p-value가 0.05보다 작은 변수의 회귀계수를 구하시오. 단 절편항(상수항)은 제외한다. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: -0.002

print('\n======p-value가 0.05보다 작은 변수의 회귀계수. 단 절편항(상수항)은 제외=======')
from statsmodels.formula.api import logit
formula = 'attrition ~ age + income + C(overtime)'
model = logit(formula, data=df).fit()

cond = model.pvalues < 0.05
under_var = model.pvalues.loc[cond].drop('Intercept').index[0]

coef = model.params[under_var]
print(round(coef,3))


# 2. 나이(age)가 1 증가할 때 이직할 오즈비(Odds Ratio)를 구하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.996
print('\n======오즈비(Odds Ratio)=======')
import numpy as np
odds_ratio = np.exp(model.params['age'])
print(round(odds_ratio,3))


# 3. 새로운 직원(age=40, income=4500, overtime=1)에 대해, 모델을 이용하여 이직 확률을 예측하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.697
print('\n======이직 확률을 예측=======')
new_data = pd.DataFrame({
    'age' : [40], # 2차원 구조여야 함. 
    'income': [4500],
    'overtime' : [1]
})
pred = model.predict(new_data).iloc[0]
print(round(pred,3))
# Out:
# ======p-value가 0.05보다 작은 변수의 회귀계수. 단 절편항(상수항)은 제외=======
# Optimization terminated successfully.
#          Current function value: 0.387298
#          Iterations 7
# -0.002
#
# ======오즈비(Odds Ratio)=======
# 0.996
#
# ======이직 확률을 예측=======
# 0.697

# %% [markdown]
# ### 문제2.
#
# 제공된 데이터(heating_load.csv)는 건물 특성과 난방 부하(heating_load)에 관한 자료이다.
# 다중회귀분석을 수행하고 제시된 소문항에 답하시오.
#
# [제공 데이터]
# - heating_load : 난방 부하 (종속변수)
# - wall : 벽체 면적
# - roof : 지붕 면적
# - glazing : 유리(창호) 면적
# - height : 건물 높이
#
# 1. 모든 독립변수를 포함한 회귀모형을 적합하시오. 이때 절편을 제외한 회귀계수의 합을 구하시오.(반올림하여 소수 셋째 자리까지 작성)
#
# 2. 유의한 변수(유의수준 0.05 이하)만을 사용하여 다중회귀분석을 다시 수행하고, R²(결정계수) 값을 구하시오. (반올림하여 소수 셋째 자리까지 작성)
#
# 3. 새로운 건물(wall=20, roof=150, glazing=20, height=5)이 주어졌을 때, 2-2문제에서 사용한 모델을 이용하여 난방 부하(heating_load)를 예측하시오. (반올림하여 소수 셋째 자리까지 작성)

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/heating.csv")

# 1. 모든 독립변수를 포함한 회귀모형을 적합하시오. 이때 절편을 제외한 회귀계수의 합을 구하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# # 답: 0.254
from statsmodels.formula.api import ols
# formula = 'heating_load ~ wall + roof+ glazing + height'

# model = ols(formula , data = df).fit()

# cond = model.params
# result = cond.iloc[1:].sum()
# print(round(result,3))

# OLS Regression Results                            
# ==============================================================================
# Dep. Variable:           heating_load   R-squared:                       0.754
# Model:                            OLS   Adj. R-squared:                  0.752
# Method:                 Least Squares   F-statistic:                     417.8
# Date:                Fri, 28 Nov 2025   Prob (F-statistic):          2.02e-164
# Time:                        20:24:08   Log-Likelihood:                -1772.0
# No. Observations:                 550   AIC:                             3554.
# Df Residuals:                     545   BIC:                             3576.
# Df Model:                           4                                         
# Covariance Type:            nonrobust                                         
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept     38.3821      1.504     25.517      0.000      35.427      41.337
# wall           0.0304      0.030      1.012      0.312      -0.029       0.090
# roof           0.2483      0.006     39.564      0.000       0.236       0.261
# glazing        0.2217      0.023      9.693      0.000       0.177       0.267
# height        -0.2469      0.077     -3.212      0.001      -0.398      -0.096
# ==============================================================================
# Omnibus:                        0.698   Durbin-Watson:                   1.896
# Prob(Omnibus):                  0.705   Jarque-Bera (JB):                0.785
# Skew:                          -0.077   Prob(JB):                        0.675
# Kurtosis:                       2.899   Cond. No.                         805.
# ==============================================================================

# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.



# 2. 유의한 변수(유의수준 0.05 이하)만을 사용하여 다중회귀분석을 다시 수행하고, R²(결정계수) 값을 구하시오. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.754

pred = model.pvalues
# print(pred<0.05)
# 0.254
# Intercept     True
# wall         False
# roof          True
# glazing       True
# height        True
# dtype: bool

formula = 'heating_load ~ roof+ glazing + height'
model = ols(formula , data = df).fit()
print(round(model.rsquared,3))


# 3. 새로운 건물(wall=20, roof=150, glazing=20, height=5)이 주어졌을 때, 2-2문제에서 사용한 모델을 이용하여 난방 부하(heating_load)를 예측하시오. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 79.612

new_data = pd.DataFrame({
    'wall':[20],
    'roof':[150],
    'glazing':[20],
    'height':[5]
})

pred = model.predict(new_data)

print(round(pred,3))
# Out:
# 0.754
# 0    79.612
# dtype: float64

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/lovedlim/inf/refs/heads/main/p4/10_3/heating.csv")

# 1. 모든 독립변수를 포함한 회귀모형을 적합하시오. 이때 절편을 제외한 회귀계수의 합을 구하시오.
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.254
print('\n======회귀계수의 합=======')
from statsmodels.formula.api import ols
formula = 'heating_load ~ wall + roof + glazing + height'
model = ols(formula, data=df).fit()

coef = model.params.drop('Intercept')
total_coef = coef.sum()
print(round(total_coef,3))


# 2. 유의한 변수(유의수준 0.05 이하)만을 사용하여 다중회귀분석을 다시 수행하고, R²(결정계수) 값을 구하시오. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 0.754
print('\n======R²(결정계수) 값=======')
pd.set_option('display.float_format', "{:.10f}".format)
pvalues = model.pvalues
cond = pvalues < 0.05
under_pvalues = pvalues[cond]

formula = 'heating_load ~ roof + glazing + height'
model = ols(formula, data=df).fit()

rsquared = model.rsquared
print(round(rsquared,3))

# 3. 새로운 건물(wall=20, roof=150, glazing=20, height=5)이 주어졌을 때, 2-2문제에서 사용한 모델을 이용하여 난방 부하(heating_load)를 예측하시오. 
# (반올림하여 소수 셋째 자리까지 작성)
# 답: 79.612
print('\n======난방 부하(heating_load)를 예측=======')
new_data = pd.DataFrame({
    'wall': [20], # 모델에서 만약에 변수에 없으면 알아서 빼고 수행한다. 그래서 있어도 상관없다. 
    'roof': [150],
    'glazing': [20],
    'height': [5],
})
pred = model.predict(new_data).values[0]
print(round(pred,3))
# Out:
# ======회귀계수의 합=======
# 0.254
#
# ======R²(결정계수) 값=======
# 0.754
#
# ======난방 부하(heating_load)를 예측=======
# 79.612

# %% [markdown]
# # 📌 예시문제 (ver.2025)

# %% [markdown]
# ### 제1유형
#
# 제공된 데이터(employee_performance.csv)는 회사의 직원 연봉과 근속 연수 등에 관한 자료이다.
# 아래 수행 순서에 따라 데이터를 처리한 후, 구한 답을 소문항별로 [제출 형식]에 맞춰 답안 제출 페이지에 답안을 입력하시오.
#
# 제공 데이터
# - 직원ID: 고유 식별자
# - 부서: 소속 부서
# - 연봉: 연간 급여
# - 근속연수: 총 근무기간
# - 성과등급: 성과 등급 A, B, C
# - 교육참여횟수: 회사 교육에 참여한 횟수
# - 고객만족도: 담당 업무에 대한 고객의 만족도
#
# 수행 순서
#
# 1) 고객만족도가 없는 직원의 경우, 평균 고객만족도로 결측치를 채운다.
#
# 2) 근속연수가 없는 직원의 경우, 해당 직원의 데이터를 삭제한다.
#
# 3) 직원의 고객만족도의 4분위 수의 3분위수를 계산한다.
#
# 4) 첫 번째로 평균연봉을 구하고, 두 번째로 평균연봉이 높은 부서의 평균연봉을 계산한다.
#
# ① 수행순서 3)에서 계산한 값을 입력하십시오.
# ※ [제출 형식] 비례하여 정수(integer)로 작성
#
# ② 수행순서 4)에서 계산한 값을 입력하십시오.
# ※ [제출 형식] 비례하여 정수(integer)로 작성

# %%
import pandas as pd
df = pd.read_csv("../../data/part4/ex/employee_performance.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[58], line 2
#       1 import pandas as pd
# ----> 2 df = pd.read_csv("../../data/part4/ex/employee_performance.csv")
#
# ...

# %% [markdown]
# ### 제2유형
#
# 유형 프로그래밍
#
# 제공된 학습용 데이터(customer_train.csv)는 백화점 고객의 1년간 상품 구매 기록이다.
# 학습용 데이터를 활용하여 총구매액을 예측하는 모형을 개발하고,
# 모형을 평가용 데이터(customer_test.csv)에 적용하여 총구매액을 예측하시오.
# 예측 결과는 아래의 [유의 사항]과 [제출 형식]을 준수하여, CSV 파일로 생성하는 코드를 제출하시오.
#
# 【유의 사항】
# ① 예측 결과는 RMSE(Root Mean Squared Error) 평가지표에 따라 평가함
# ② 우수한 평가지표 획득을 위해 다양한 모형을 대상으로 초매개변수 조합을 탐색하고 비교하여 최적의 모형을 찾는 과정이 필요함
#
# 【제출 형식】
# ① CSV 파일명: result.csv (파일명에 디렉토리·폴더 지정 불가)
# ② 예측 총 구매금액 칼럼명: pred
# ③ 제출 칼럼 개수: pred 칼럼 1개
# ④ 평가용 데이터 개수와 예측 결과 데이터 개수 일치: 2,482개

# %%
import pandas as pd
train = pd.read_csv("https://dataq.goorm.io/input-file/content?quizIndex=q_Dlldj_1730448300236&fileName=data%2Fcustomer_train.csv")
test = pd.read_csv("https://dataq.goorm.io/input-file/content?quizIndex=q_Dlldj_1730448300236&fileName=data%2Fcustomer_test.csv")

# %% [markdown]
# ### 제3유형
#
# 제공된 데이터(bcc.csv)는 암 환자와 정상인의 리지스틴 수치에 대한 자료이며,
# 두 집단의 로그 리지스틴 값에 차이가 있는지를 검정하려고 한다.
# 소문항별로 답을 구한 후, 구한 답을 제시된 [제출 형식]에 맞춰 제출 페이제에 입력하시오.
# (단, 모델은 절편항을 포함한다.)
#
# 제공 데이터
#
# Resistin: 리지스틴 수치(ng/mL)
#
# Classification: 실험자 정보(1: 정상, 2: 환자)
#
# ①두 집단의 로그 리지스틴 값의 분산에 차이가 있는지를 알아보기 위해 F-검정을 수행할 때 검정통계량의 값을 구하라.
# (단, 분자의 자유도가 분모의 자유도보다 크도록 하여라.)
# [제출 형식] 반올림하여 소수 셋째 자리까지 작성
#
# ②두 집단의 로그 리지스틴 값에 대한 합동 분산 추정량을 구하여라.
# [제출 형식] 반올림하여 소수 셋째 자리까지 작성
#
# ③ ②번 문제에서 구한 합동 분산 추정량을 이용하여 두 집단의 로그 리지스틴 값에 유의미한 차이가 있는지 독립표본 t-검정을 수행하고 p-value 값을 구하여라.
# [제출 형식] 반올림하여 소수 셋째 자리까지 작성

# %%
import pandas as pd
df = pd.read_csv("../../data/part4/ex/bcc.csv")
